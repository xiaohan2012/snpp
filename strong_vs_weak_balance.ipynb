# %%
# max_balance that uses only strong balance (equivalent to making cluster labels universally identical)
# iterative approach that uses weak balance
# predict 100, 200, ..., 2000 edges

# result:
# plot of two lines
# x-axis: edge count (budget)
# y-axis: accuracy

# %%
import _pickle as pkl
import networkx as nx
import numpy as np
import random

from tqdm import tqdm
from snpp.cores.lowrank import alq_spark, predict_signs
from snpp.utils.matrix import split_train_test, load_sparse_csr
from snpp.utils.signed_graph import g2m
from snpp.utils.data import load_train_test_graphs
from snpp.utils.edge_filter import filter_by_min_triangle_count
from snpp.utils.evaluation import accuracy

from snpp.utils.spark import sc

dataset = 'slashdot'
lambda_ = 0.2
k = 10
max_iter = 100
random_seed = 123456
min_tri_count = 30

recache_input = False

random.seed(random_seed)
np.random.seed(random_seed)

# %%
train_g, test_g = load_train_test_graphs(dataset, recache_input)
train_g_ud = train_g.to_undirected()
# Out:
# loading train and test graphs...

# %%
confident_edges = set(filter_by_min_triangle_count(train_g_ud, test_g.edges(), min_tri_count))

# %%
from snpp.cores.joint_part_pred import iterative_approach
from snpp.cores.max_balance import faster_greedy
from snpp.cores.lowrank import partition_graph
from snpp.cores.budget_allocation import constant_budget
from snpp.cores.triangle import build_edge2edges

common_params = dict(
    g=train_g_ud,
    T=confident_edges,
    k=k,
    budget_allocation_f=constant_budget,
    solve_maxbalance_f=faster_greedy,
    solve_maxbalance_kwargs={'edge2edges': build_edge2edges(train_g_ud.copy(),
                                                            confident_edges)},
    truth=set([(i, j, test_g[i][j]['sign'])
               for i, j in confident_edges]),
    perform_last_partition=False
)
# Out:
#  21%|██        | 373/1819 [00:00<00:00, 1878.81it/s]
# build edge2edges
# 100%|██████████| 1819/1819 [00:01<00:00, 1760.19it/s]

# %%
# storng balance approach
def partition_into_one(g, *args, **kwargs):
    return np.ones(g.number_of_nodes())

part, strong_preds, _ = iterative_approach(
    graph_partition_f=partition_into_one,
    budget_allocation_kwargs=dict(const=len(confident_edges)),
    **common_params)

print(" => accuracy {} (strong balance)".format(accuracy(test_g, strong_preds)))
# Out:
# iteration=1, #remaining targets=1819
# graph partitioning...
# solving max_balance
# building triangle_count_by_edge
# edge2edges (size 1668) is given
# ✓ assigning 1 to (74, 87) produces 187 more balanced triangles (1, 188): (('s+1', 188), ('s-1', 1))
# ✓ assigning 1 to (75, 74) produces 185 more balanced triangles (15, 200): (('s+1', 200), ('s-1', 15))
# ✓ assigning 1 to (913, 867) produces 183 more balanced triangles (0, 183): (('s+1', 183),)
# ✓ assigning 1 to (648, 936) produces 183 more balanced triangles (2, 185): (('s+1', 185), ('s-1', 2))
# ✓ assigning 1 to (74, 82) produces 176 more balanced triangles (6, 182): (('s+1', 182), ('s-1', 6))
# ✓ assigning 1 to (87, 936) produces 174 more balanced triangles (0, 174): (('s+1', 174),)
# ✓ assigning 1 to (867, 74) produces 172 more balanced triangles (2, 174): (('s+1', 174), ('s-1', 2))
# ✓ assigning 1 to (83, 936) produces 167 more balanced triangles (1, 168): (('s+1', 168), ('s-1', 1))
# ✓ assigning 1 to (43, 34) produces 164 more balanced triangles (15, 179): (('s+1', 179), ('s-1', 15))
# ✓ assigning 1 to (867, 936) produces 164 more balanced triangles (0, 164): (('s+1', 164),)
# ✓ assigning 1 to (1033, 74) produces 163 more balanced triangles (0, 163): (('s+1', 163),)
# ✓ assigning 1 to (74, 43) produces 162 more balanced triangles (17, 179): (('s+1', 179), ('s-1', 17))
# ✓ assigning 1 to (82, 648) produces 161 more balanced triangles (1, 162): (('s+1', 162), ('s-1', 1))
# ✓ assigning 1 to (913, 841) produces 159 more balanced triangles (0, 159): (('s+1', 159),)
# ✓ assigning 1 to (648, 87) produces 151 more balanced triangles (0, 151): (('s+1', 151),)
# ✓ assigning 1 to (82, 1033) produces 150 more balanced triangles (2, 152): (('s+1', 152), ('s-1', 2))
# ✓ assigning 1 to (936, 2452) produces 148 more balanced triangles (0, 148): (('s+1', 148),)
# ✓ assigning 1 to (1006, 1033) produces 148 more balanced triangles (1, 149): (('s+1', 149), ('s-1', 1))
# ✓ assigning 1 to (1033, 1006) produces 148 more balanced triangles (1, 149): (('s+1', 149), ('s-1', 1))
# ✓ assigning 1 to (20799, 1491) produces 146 more balanced triangles (3, 149): (('s+1', 149), ('s-1', 3))
# ✓ assigning 1 to (945, 74) produces 144 more balanced triangles (1, 145): (('s+1', 145), ('s-1', 1))
# ✓ assigning 1 to (841, 74) produces 143 more balanced triangles (0, 143): (('s+1', 143),)
# ✓ assigning 1 to (648, 83) produces 141 more balanced triangles (1, 142): (('s+1', 142), ('s-1', 1))
# ✓ assigning 1 to (648, 1033) produces 140 more balanced triangles (2, 142): (('s+1', 142), ('s-1', 2))
# ✓ assigning 1 to (1043, 82) produces 139 more balanced triangles (3, 142): (('s+1', 142), ('s-1', 3))
# ✓ assigning 1 to (82, 1043) produces 139 more balanced triangles (3, 142): (('s+1', 142), ('s-1', 3))
# ✓ assigning 1 to (4808, 791) produces 138 more balanced triangles (1, 139): (('s+1', 139), ('s-1', 1))
# ✓ assigning 1 to (860, 791) produces 137 more balanced triangles (1, 138): (('s+1', 138), ('s-1', 1))
# ✓ assigning 1 to (841, 867) produces 137 more balanced triangles (0, 137): (('s+1', 137),)
# ✓ assigning 1 to (936, 973) produces 136 more balanced triangles (5, 141): (('s+1', 141), ('s-1', 5))
# ✓ assigning 1 to (648, 71) produces 136 more balanced triangles (3, 139): (('s+1', 139), ('s-1', 3))
# ✓ assigning 1 to (841, 1006) produces 136 more balanced triangles (0, 136): (('s+1', 136),)
# ✓ assigning 1 to (4256, 936) produces 135 more balanced triangles (1, 136): (('s+1', 136), ('s-1', 1))
# ✓ assigning 1 to (648, 65) produces 133 more balanced triangles (2, 135): (('s+1', 135), ('s-1', 2))
# ✓ assigning 1 to (896, 74) produces 128 more balanced triangles (0, 128): (('s+1', 128),)
# ✓ assigning 1 to (2452, 867) produces 128 more balanced triangles (0, 128): (('s+1', 128),)
# ✓ assigning 1 to (1200, 791) produces 128 more balanced triangles (0, 128): (('s+1', 128),)
# ✓ assigning 1 to (896, 83) produces 128 more balanced triangles (0, 128): (('s+1', 128),)
# ✓ assigning 1 to (62, 87) produces 127 more balanced triangles (0, 127): (('s+1', 127),)
# ✓ assigning 1 to (2420, 82) produces 127 more balanced triangles (5, 132): (('s+1', 132), ('s-1', 5))
# ✓ assigning 1 to (1197, 936) produces 127 more balanced triangles (1, 128): (('s+1', 128), ('s-1', 1))
# ✓ assigning 1 to (87, 62) produces 127 more balanced triangles (0, 127): (('s+1', 127),)
# ✓ assigning 1 to (83, 2458) produces 126 more balanced triangles (4, 130): (('s+1', 130), ('s-1', 4))
# ✓ assigning 1 to (83, 70) produces 125 more balanced triangles (0, 125): (('s+1', 125),)
# ✓ assigning 1 to (896, 82) produces 125 more balanced triangles (1, 126): (('s+1', 126), ('s-1', 1))
# ✓ assigning 1 to (87, 2458) produces 125 more balanced triangles (1, 126): (('s+1', 126), ('s-1', 1))
# ✓ assigning 1 to (973, 1043) produces 124 more balanced triangles (2, 126): (('s+1', 126), ('s-1', 2))
# ✓ assigning 1 to (1043, 973) produces 123 more balanced triangles (2, 125): (('s+1', 125), ('s-1', 2))
# ✓ assigning 1 to (87, 973) produces 123 more balanced triangles (7, 130): (('s+1', 130), ('s-1', 7))
# ✓ assigning 1 to (1043, 867) produces 121 more balanced triangles (1, 122): (('s+1', 122), ('s-1', 1))
# ✓ assigning 1 to (74, 962) produces 121 more balanced triangles (1, 122): (('s+1', 122), ('s-1', 1))
# ✓ assigning 1 to (2420, 867) produces 119 more balanced triangles (1, 120): (('s+1', 120), ('s-1', 1))
# ✓ assigning 1 to (896, 1006) produces 119 more balanced triangles (0, 119): (('s+1', 119),)
# ✓ assigning 1 to (913, 1029) produces 119 more balanced triangles (3, 122): (('s+1', 122), ('s-1', 3))
# ✓ assigning 1 to (749, 75) produces 119 more balanced triangles (44, 163): (('s+1', 163), ('s-1', 44))
# ✓ assigning 1 to (936, 1043) produces 117 more balanced triangles (0, 117): (('s+1', 117),)
# ✓ assigning 1 to (791, 71) produces 117 more balanced triangles (0, 117): (('s+1', 117),)
# ✓ assigning 1 to (936, 945) produces 116 more balanced triangles (0, 116): (('s+1', 116),)
# ✓ assigning 1 to (2452, 791) produces 115 more balanced triangles (0, 115): (('s+1', 115),)
# ✓ assigning 1 to (70, 82) produces 114 more balanced triangles (1, 115): (('s+1', 115), ('s-1', 1))
# ✓ assigning 1 to (2458, 2452) produces 114 more balanced triangles (0, 114): (('s+1', 114),)
# ✓ assigning 1 to (913, 988) produces 114 more balanced triangles (0, 114): (('s+1', 114),)
# ✓ assigning 1 to (936, 70) produces 114 more balanced triangles (0, 114): (('s+1', 114),)
# ✓ assigning 1 to (97, 867) produces 112 more balanced triangles (1, 113): (('s+1', 113), ('s-1', 1))
# ✓ assigning 1 to (841, 648) produces 112 more balanced triangles (2, 114): (('s+1', 114), ('s-1', 2))
# ✓ assigning 1 to (1033, 896) produces 111 more balanced triangles (0, 111): (('s+1', 111),)
# ✓ assigning 1 to (867, 97) produces 111 more balanced triangles (1, 112): (('s+1', 112), ('s-1', 1))
# ✓ assigning 1 to (74, 1029) produces 111 more balanced triangles (3, 114): (('s+1', 114), ('s-1', 3))
# ✓ assigning 1 to (791, 880) produces 109 more balanced triangles (0, 109): (('s+1', 109),)
# ✓ assigning 1 to (1029, 936) produces 109 more balanced triangles (3, 112): (('s+1', 112), ('s-1', 3))
# ✓ assigning 1 to (64, 65) produces 109 more balanced triangles (5, 114): (('s+1', 114), ('s-1', 5))
# ✓ assigning 1 to (856, 74) produces 108 more balanced triangles (1, 109): (('s+1', 109), ('s-1', 1))
# ✓ assigning 1 to (65, 64) produces 108 more balanced triangles (5, 113): (('s+1', 113), ('s-1', 5))
# ✓ assigning 1 to (1053, 841) produces 107 more balanced triangles (0, 107): (('s+1', 107),)
# ✓ assigning 1 to (867, 62) produces 107 more balanced triangles (1, 108): (('s+1', 108), ('s-1', 1))
# ✓ assigning 1 to (97, 1006) produces 107 more balanced triangles (2, 109): (('s+1', 109), ('s-1', 2))
# ✓ assigning 1 to (70, 87) produces 107 more balanced triangles (1, 108): (('s+1', 108), ('s-1', 1))
# ✓ assigning 1 to (896, 867) produces 107 more balanced triangles (0, 107): (('s+1', 107),)
# ✓ assigning 1 to (87, 97) produces 107 more balanced triangles (1, 108): (('s+1', 108), ('s-1', 1))
# ✓ assigning 1 to (809, 71) produces 106 more balanced triangles (0, 106): (('s+1', 106),)
# ✓ assigning 1 to (2458, 65) produces 106 more balanced triangles (3, 109): (('s+1', 109), ('s-1', 3))
# ✓ assigning 1 to (791, 1029) produces 106 more balanced triangles (5, 111): (('s+1', 111), ('s-1', 5))
# ✓ assigning 1 to (1053, 867) produces 106 more balanced triangles (0, 106): (('s+1', 106),)
# ✓ assigning 1 to (87, 70) produces 106 more balanced triangles (1, 107): (('s+1', 107), ('s-1', 1))
# ✓ assigning 1 to (1006, 97) produces 105 more balanced triangles (2, 107): (('s+1', 107), ('s-1', 2))
# ✓ assigning 1 to (82, 653) produces 105 more balanced triangles (1, 106): (('s+1', 106), ('s-1', 1))
# ✓ assigning 1 to (820, 913) produces 105 more balanced triangles (0, 105): (('s+1', 105),)
# ✓ assigning 1 to (860, 66) produces 104 more balanced triangles (1, 105): (('s+1', 105), ('s-1', 1))
# ✓ assigning 1 to (2454, 913) produces 104 more balanced triangles (0, 104): (('s+1', 104),)
# ✓ assigning 1 to (1389, 83) produces 103 more balanced triangles (0, 103): (('s+1', 103),)
# ✓ assigning 1 to (913, 2442) produces 103 more balanced triangles (0, 103): (('s+1', 103),)
# ✓ assigning 1 to (87, 945) produces 103 more balanced triangles (0, 103): (('s+1', 103),)
# ✓ assigning 1 to (1171, 4808) produces 103 more balanced triangles (1, 104): (('s+1', 104), ('s-1', 1))
# ✓ assigning 1 to (1061, 860) produces 103 more balanced triangles (0, 103): (('s+1', 103),)
# ✓ assigning 1 to (4808, 936) produces 102 more balanced triangles (1, 103): (('s+1', 103), ('s-1', 1))
# ✓ assigning 1 to (818, 83) produces 102 more balanced triangles (0, 102): (('s+1', 102),)
# ✓ assigning 1 to (87, 2354) produces 102 more balanced triangles (1, 103): (('s+1', 103), ('s-1', 1))
# ✓ assigning 1 to (841, 1029) produces 102 more balanced triangles (4, 106): (('s+1', 106), ('s-1', 4))
# ✓ assigning 1 to (74, 817) produces 101 more balanced triangles (0, 101): (('s+1', 101),)
# ✓ assigning 1 to (1006, 881) produces 101 more balanced triangles (0, 101): (('s+1', 101),)
# ✓ assigning 1 to (1029, 1043) produces 101 more balanced triangles (2, 103): (('s+1', 103), ('s-1', 2))
# ✓ assigning 1 to (653, 2354) produces 101 more balanced triangles (2, 103): (('s+1', 103), ('s-1', 2))
# ✓ assigning 1 to (880, 65) produces 100 more balanced triangles (0, 100): (('s+1', 100),)
# ✓ assigning 1 to (50, 28) produces 99 more balanced triangles (1, 100): (('s+1', 100), ('s-1', 1))
# ✓ assigning 1 to (62, 2452) produces 99 more balanced triangles (1, 100): (('s+1', 100), ('s-1', 1))
# ✓ assigning 1 to (982, 74) produces 99 more balanced triangles (0, 99): (('s+1', 99),)
# ✓ assigning 1 to (2452, 833) produces 99 more balanced triangles (2, 101): (('s+1', 101), ('s-1', 2))
# ✓ assigning 1 to (8, 913) produces 98 more balanced triangles (0, 98): (('s+1', 98),)
# ✓ assigning 1 to (1061, 841) produces 98 more balanced triangles (0, 98): (('s+1', 98),)
# ✓ assigning 1 to (820, 83) produces 98 more balanced triangles (0, 98): (('s+1', 98),)
# ✓ assigning 1 to (62, 896) produces 98 more balanced triangles (0, 98): (('s+1', 98),)
# ✓ assigning 1 to (913, 1239) produces 98 more balanced triangles (0, 98): (('s+1', 98),)
# ✓ assigning 1 to (67, 82) produces 97 more balanced triangles (2, 99): (('s+1', 99), ('s-1', 2))
# ✓ assigning 1 to (87, 842) produces 96 more balanced triangles (0, 96): (('s+1', 96),)
# ✓ assigning 1 to (860, 809) produces 96 more balanced triangles (2, 98): (('s+1', 98), ('s-1', 2))
# ✓ assigning 1 to (842, 936) produces 96 more balanced triangles (0, 96): (('s+1', 96),)
# ✓ assigning 1 to (867, 61) produces 96 more balanced triangles (0, 96): (('s+1', 96),)
# ✓ assigning 1 to (2452, 62) produces 96 more balanced triangles (1, 97): (('s+1', 97), ('s-1', 1))
# ✓ assigning 1 to (880, 62) produces 96 more balanced triangles (1, 97): (('s+1', 97), ('s-1', 1))
# ✓ assigning 1 to (936, 1389) produces 95 more balanced triangles (0, 95): (('s+1', 95),)
# ✓ assigning 1 to (1012, 818) produces 95 more balanced triangles (1, 96): (('s+1', 96), ('s-1', 1))
# ✓ assigning 1 to (971, 74) produces 95 more balanced triangles (0, 95): (('s+1', 95),)
# ✓ assigning 1 to (70, 2452) produces 95 more balanced triangles (0, 95): (('s+1', 95),)
# ✓ assigning 1 to (4256, 2420) produces 95 more balanced triangles (2, 97): (('s+1', 97), ('s-1', 2))
# ✓ assigning 1 to (888, 936) produces 94 more balanced triangles (1, 95): (('s+1', 95), ('s-1', 1))
# ✓ assigning 1 to (648, 881) produces 94 more balanced triangles (2, 96): (('s+1', 96), ('s-1', 2))
# ✓ assigning 1 to (842, 87) produces 94 more balanced triangles (0, 94): (('s+1', 94),)
# ✓ assigning 1 to (95, 82) produces 94 more balanced triangles (2, 96): (('s+1', 96), ('s-1', 2))
# ✓ assigning 1 to (1193, 913) produces 93 more balanced triangles (0, 93): (('s+1', 93),)
# ✓ assigning 1 to (2458, 70) produces 93 more balanced triangles (0, 93): (('s+1', 93),)
# ✓ assigning 1 to (4256, 648) produces 93 more balanced triangles (4, 97): (('s+1', 97), ('s-1', 4))
# ✓ assigning 1 to (2442, 936) produces 93 more balanced triangles (0, 93): (('s+1', 93),)
# ✓ assigning 1 to (867, 2066) produces 93 more balanced triangles (2, 95): (('s+1', 95), ('s-1', 2))
# ✓ assigning 1 to (880, 945) produces 92 more balanced triangles (0, 92): (('s+1', 92),)
# ✓ assigning 1 to (65, 2354) produces 92 more balanced triangles (2, 94): (('s+1', 94), ('s-1', 2))
# ✓ assigning 1 to (896, 1053) produces 92 more balanced triangles (0, 92): (('s+1', 92),)
# ✓ assigning 1 to (74, 2043) produces 92 more balanced triangles (1, 93): (('s+1', 93), ('s-1', 1))
# ✓ assigning 1 to (1061, 2452) produces 92 more balanced triangles (0, 92): (('s+1', 92),)
# ✓ assigning 1 to (841, 1389) produces 91 more balanced triangles (0, 91): (('s+1', 91),)
# ✓ assigning 1 to (2470, 936) produces 91 more balanced triangles (0, 91): (('s+1', 91),)
# ✓ assigning 1 to (841, 66) produces 91 more balanced triangles (0, 91): (('s+1', 91),)
# ✓ assigning 1 to (913, 2808) produces 91 more balanced triangles (1, 92): (('s+1', 92), ('s-1', 1))
# ✓ assigning 1 to (74, 2407) produces 91 more balanced triangles (0, 91): (('s+1', 91),)
# ✓ assigning 1 to (856, 1033) produces 91 more balanced triangles (0, 91): (('s+1', 91),)
# ✓ assigning 1 to (74, 2404) produces 92 more balanced triangles (0, 92): (('s+1', 92),)
# ✓ assigning 1 to (3773, 74) produces 91 more balanced triangles (0, 91): (('s+1', 91),)
# ✓ assigning 1 to (62, 43) produces 91 more balanced triangles (3, 94): (('s+1', 94), ('s-1', 3))
# ✓ assigning 1 to (2354, 841) produces 90 more balanced triangles (2, 92): (('s+1', 92), ('s-1', 2))
# ✓ assigning 1 to (65, 1061) produces 89 more balanced triangles (2, 91): (('s+1', 91), ('s-1', 2))
# ✓ assigning 1 to (62, 973) produces 89 more balanced triangles (4, 93): (('s+1', 93), ('s-1', 4))
# ✓ assigning 1 to (65, 798) produces 89 more balanced triangles (1, 90): (('s+1', 90), ('s-1', 1))
# ✓ assigning 1 to (856, 860) produces 89 more balanced triangles (2, 91): (('s+1', 91), ('s-1', 2))
# ✓ assigning 1 to (61, 65) produces 89 more balanced triangles (0, 89): (('s+1', 89),)
# ✓ assigning 1 to (83, 2043) produces 89 more balanced triangles (0, 89): (('s+1', 89),)
# ✓ assigning 1 to (82, 1239) produces 89 more balanced triangles (0, 89): (('s+1', 89),)
# ✓ assigning 1 to (856, 82) produces 89 more balanced triangles (2, 91): (('s+1', 91), ('s-1', 2))
# ✓ assigning 1 to (65, 66) produces 88 more balanced triangles (0, 88): (('s+1', 88),)
# ✓ assigning 1 to (833, 841) produces 88 more balanced triangles (9, 97): (('s+1', 97), ('s-1', 9))
# ✓ assigning 1 to (2407, 74) produces 88 more balanced triangles (0, 88): (('s+1', 88),)
# ✓ assigning 1 to (856, 913) produces 88 more balanced triangles (0, 88): (('s+1', 88),)
# ✓ assigning 1 to (74, 1988) produces 88 more balanced triangles (5, 93): (('s+1', 93), ('s-1', 5))
# ✓ assigning 1 to (4808, 841) produces 88 more balanced triangles (2, 90): (('s+1', 90), ('s-1', 2))
# ✓ assigning 1 to (977, 791) produces 88 more balanced triangles (0, 88): (('s+1', 88),)
# ✓ assigning 1 to (858, 860) produces 88 more balanced triangles (1, 89): (('s+1', 89), ('s-1', 1))
# ✓ assigning 1 to (860, 2407) produces 87 more balanced triangles (1, 88): (('s+1', 88), ('s-1', 1))
# ✓ assigning 1 to (936, 1988) produces 87 more balanced triangles (0, 87): (('s+1', 87),)
# ✓ assigning 1 to (1935, 83) produces 87 more balanced triangles (1, 88): (('s+1', 88), ('s-1', 1))
# ✓ assigning 1 to (977, 82) produces 87 more balanced triangles (1, 88): (('s+1', 88), ('s-1', 1))
# ✓ assigning 1 to (1061, 1033) produces 87 more balanced triangles (1, 88): (('s+1', 88), ('s-1', 1))
# ✓ assigning 1 to (62, 8) produces 87 more balanced triangles (2, 89): (('s+1', 89), ('s-1', 2))
# ✓ assigning 1 to (1043, 70) produces 87 more balanced triangles (0, 87): (('s+1', 87),)
# ✓ assigning 1 to (860, 1019) produces 87 more balanced triangles (3, 90): (('s+1', 90), ('s-1', 3))
# ✓ assigning 1 to (2420, 817) produces 87 more balanced triangles (0, 87): (('s+1', 87),)
# ✓ assigning 1 to (859, 648) produces 87 more balanced triangles (2, 89): (('s+1', 89), ('s-1', 2))
# ✓ assigning 1 to (867, 3773) produces 86 more balanced triangles (0, 86): (('s+1', 86),)
# ✓ assigning 1 to (4256, 1061) produces 86 more balanced triangles (0, 86): (('s+1', 86),)
# ✓ assigning 1 to (97, 798) produces 86 more balanced triangles (2, 88): (('s+1', 88), ('s-1', 2))
# ✓ assigning 1 to (841, 653) produces 86 more balanced triangles (4, 90): (('s+1', 90), ('s-1', 4))
# ✓ assigning 1 to (87, 2043) produces 86 more balanced triangles (0, 86): (('s+1', 86),)
# ✓ assigning 1 to (1006, 982) produces 86 more balanced triangles (0, 86): (('s+1', 86),)
# ✓ assigning 1 to (936, 590) produces 86 more balanced triangles (0, 86): (('s+1', 86),)
# ✓ assigning 1 to (945, 83) produces 86 more balanced triangles (0, 86): (('s+1', 86),)
# ✓ assigning 1 to (798, 880) produces 86 more balanced triangles (2, 88): (('s+1', 88), ('s-1', 2))
# ✓ assigning 1 to (791, 1151) produces 85 more balanced triangles (2, 87): (('s+1', 87), ('s-1', 2))
# ✓ assigning 1 to (653, 190) produces 85 more balanced triangles (5, 90): (('s+1', 90), ('s-1', 5))
# ✓ assigning 1 to (1061, 791) produces 85 more balanced triangles (0, 85): (('s+1', 85),)
# ✓ assigning 1 to (152, 936) produces 85 more balanced triangles (0, 85): (('s+1', 85),)
# ✓ assigning 1 to (1935, 867) produces 85 more balanced triangles (0, 85): (('s+1', 85),)
# ✓ assigning 1 to (817, 2452) produces 85 more balanced triangles (0, 85): (('s+1', 85),)
# ✓ assigning 1 to (8, 1053) produces 85 more balanced triangles (0, 85): (('s+1', 85),)
# ✓ assigning 1 to (1171, 2808) produces 84 more balanced triangles (0, 84): (('s+1', 84),)
# ✓ assigning 1 to (1029, 1061) produces 84 more balanced triangles (0, 84): (('s+1', 84),)
# ✓ assigning 1 to (1043, 1053) produces 84 more balanced triangles (0, 84): (('s+1', 84),)
# ✓ assigning 1 to (1389, 1043) produces 84 more balanced triangles (0, 84): (('s+1', 84),)
# ✓ assigning 1 to (1054, 648) produces 84 more balanced triangles (3, 87): (('s+1', 87), ('s-1', 3))
# ✓ assigning 1 to (913, 190) produces 83 more balanced triangles (0, 83): (('s+1', 83),)
# ✓ assigning 1 to (2458, 971) produces 83 more balanced triangles (0, 83): (('s+1', 83),)
# ✓ assigning 1 to (2808, 841) produces 83 more balanced triangles (1, 84): (('s+1', 84), ('s-1', 1))
# ✓ assigning 1 to (106, 625) produces 83 more balanced triangles (11, 94): (('s+1', 94), ('s-1', 11))
# ✓ assigning 1 to (841, 1151) produces 83 more balanced triangles (0, 83): (('s+1', 83),)
# ✓ assigning 1 to (936, 152) produces 83 more balanced triangles (0, 83): (('s+1', 83),)
# ✓ assigning 1 to (1006, 8) produces 83 more balanced triangles (0, 83): (('s+1', 83),)
# ✓ assigning 1 to (880, 842) produces 82 more balanced triangles (0, 82): (('s+1', 82),)
# ✓ assigning 1 to (1028, 82) produces 82 more balanced triangles (1, 83): (('s+1', 83), ('s-1', 1))
# ✓ assigning 1 to (955, 936) produces 82 more balanced triangles (4, 86): (('s+1', 86), ('s-1', 4))
# ✓ assigning 1 to (2420, 988) produces 82 more balanced triangles (0, 82): (('s+1', 82),)
# ✓ assigning 1 to (4256, 896) produces 82 more balanced triangles (2, 84): (('s+1', 84), ('s-1', 2))
# ✓ assigning 1 to (798, 2452) produces 82 more balanced triangles (1, 83): (('s+1', 83), ('s-1', 1))
# ✓ assigning 1 to (648, 988) produces 82 more balanced triangles (4, 86): (('s+1', 86), ('s-1', 4))
# ✓ assigning 1 to (66, 798) produces 82 more balanced triangles (0, 82): (('s+1', 82),)
# ✓ assigning 1 to (71, 95) produces 82 more balanced triangles (2, 84): (('s+1', 84), ('s-1', 2))
# ✓ assigning 1 to (2443, 83) produces 82 more balanced triangles (0, 82): (('s+1', 82),)
# ✓ assigning 1 to (74, 57) produces 82 more balanced triangles (16, 98): (('s+1', 98), ('s-1', 16))
# ✓ assigning 1 to (988, 841) produces 81 more balanced triangles (2, 83): (('s+1', 83), ('s-1', 2))
# ✓ assigning 1 to (936, 1020) produces 81 more balanced triangles (2, 83): (('s+1', 83), ('s-1', 2))
# ✓ assigning 1 to (1006, 1020) produces 81 more balanced triangles (2, 83): (('s+1', 83), ('s-1', 2))
# ✓ assigning 1 to (2354, 2066) produces 81 more balanced triangles (4, 85): (('s+1', 85), ('s-1', 4))
# ✓ assigning 1 to (67, 648) produces 81 more balanced triangles (2, 83): (('s+1', 83), ('s-1', 2))
# ✓ assigning 1 to (1053, 798) produces 81 more balanced triangles (1, 82): (('s+1', 82), ('s-1', 1))
# ✓ assigning 1 to (64, 4256) produces 80 more balanced triangles (10, 90): (('s+1', 90), ('s-1', 10))
# ✓ assigning 1 to (82, 152) produces 80 more balanced triangles (2, 82): (('s+1', 82), ('s-1', 2))
# ✓ assigning 1 to (2393, 71) produces 80 more balanced triangles (0, 80): (('s+1', 80),)
# ✓ assigning 1 to (3041, 74) produces 80 more balanced triangles (9, 89): (('s+1', 89), ('s-1', 9))
# ✓ assigning 1 to (976, 913) produces 80 more balanced triangles (11, 91): (('s+1', 91), ('s-1', 11))
# ✓ assigning 1 to (841, 1935) produces 80 more balanced triangles (1, 81): (('s+1', 81), ('s-1', 1))
# ✓ assigning 1 to (4256, 1012) produces 80 more balanced triangles (6, 86): (('s+1', 86), ('s-1', 6))
# ✓ assigning 1 to (2474, 791) produces 80 more balanced triangles (0, 80): (('s+1', 80),)
# ✓ assigning 1 to (1239, 1171) produces 80 more balanced triangles (0, 80): (('s+1', 80),)
# ✓ assigning 1 to (975, 74) produces 79 more balanced triangles (4, 83): (('s+1', 83), ('s-1', 4))
# ✓ assigning 1 to (858, 71) produces 79 more balanced triangles (0, 79): (('s+1', 79),)
# ✓ assigning 1 to (1033, 2043) produces 79 more balanced triangles (1, 80): (('s+1', 80), ('s-1', 1))
# ✓ assigning 1 to (1735, 841) produces 79 more balanced triangles (4, 83): (('s+1', 83), ('s-1', 4))
# ✓ assigning 1 to (1006, 2470) produces 79 more balanced triangles (0, 79): (('s+1', 79),)
# ✓ assigning 1 to (1053, 1061) produces 79 more balanced triangles (0, 79): (('s+1', 79),)
# ✓ assigning 1 to (1027, 973) produces 79 more balanced triangles (3, 82): (('s+1', 82), ('s-1', 3))
# ✓ assigning 1 to (82, 859) produces 79 more balanced triangles (1, 80): (('s+1', 80), ('s-1', 1))
# ✓ assigning 1 to (820, 973) produces 79 more balanced triangles (3, 82): (('s+1', 82), ('s-1', 3))
# ✓ assigning 1 to (841, 2454) produces 79 more balanced triangles (0, 79): (('s+1', 79),)
# ✓ assigning 1 to (2393, 2420) produces 78 more balanced triangles (1, 79): (('s+1', 79), ('s-1', 1))
# ✓ assigning 1 to (82, 590) produces 78 more balanced triangles (2, 80): (('s+1', 80), ('s-1', 2))
# ✓ assigning 1 to (820, 791) produces 78 more balanced triangles (0, 78): (('s+1', 78),)
# ✓ assigning 1 to (791, 858) produces 78 more balanced triangles (1, 79): (('s+1', 79), ('s-1', 1))
# ✓ assigning 1 to (648, 818) produces 78 more balanced triangles (1, 79): (('s+1', 79), ('s-1', 1))
# ✓ assigning 1 to (67, 880) produces 78 more balanced triangles (0, 78): (('s+1', 78),)
# ✓ assigning 1 to (2434, 867) produces 78 more balanced triangles (0, 78): (('s+1', 78),)
# ✓ assigning 1 to (78, 913) produces 78 more balanced triangles (0, 78): (('s+1', 78),)
# ✓ assigning 1 to (2393, 2458) produces 78 more balanced triangles (1, 79): (('s+1', 79), ('s-1', 1))
# ✓ assigning 1 to (62, 1054) produces 78 more balanced triangles (0, 78): (('s+1', 78),)
# ✓ assigning 1 to (74, 38) produces 77 more balanced triangles (11, 88): (('s+1', 88), ('s-1', 11))
# ✓ assigning 1 to (2458, 3773) produces 77 more balanced triangles (1, 78): (('s+1', 78), ('s-1', 1))
# ✓ assigning 1 to (955, 860) produces 77 more balanced triangles (5, 82): (('s+1', 82), ('s-1', 5))
# ✓ assigning 1 to (2393, 1033) produces 77 more balanced triangles (0, 77): (('s+1', 77),)
# ✓ assigning 1 to (87, 629) produces 77 more balanced triangles (3, 80): (('s+1', 80), ('s-1', 3))
# ✓ assigning 1 to (749, 945) produces 77 more balanced triangles (14, 91): (('s+1', 91), ('s-1', 14))
# ✓ assigning 1 to (87, 1707) produces 77 more balanced triangles (0, 77): (('s+1', 77),)
# ✓ assigning 1 to (1735, 64) produces 77 more balanced triangles (6, 83): (('s+1', 83), ('s-1', 6))
# ✓ assigning 1 to (82, 78) produces 77 more balanced triangles (4, 81): (('s+1', 81), ('s-1', 4))
# ✓ assigning 1 to (1029, 818) produces 77 more balanced triangles (3, 80): (('s+1', 80), ('s-1', 3))
# ✓ assigning 1 to (648, 817) produces 77 more balanced triangles (2, 79): (('s+1', 79), ('s-1', 2))
# ✓ assigning 1 to (820, 896) produces 77 more balanced triangles (0, 77): (('s+1', 77),)
# ✓ assigning 1 to (74, 590) produces 77 more balanced triangles (5, 82): (('s+1', 82), ('s-1', 5))
# ✓ assigning 1 to (2066, 841) produces 76 more balanced triangles (5, 81): (('s+1', 81), ('s-1', 5))
# ✓ assigning 1 to (1005, 913) produces 76 more balanced triangles (0, 76): (('s+1', 76),)
# ✓ assigning 1 to (4266, 65) produces 76 more balanced triangles (0, 76): (('s+1', 76),)
# ✓ assigning 1 to (2458, 67) produces 76 more balanced triangles (0, 76): (('s+1', 76),)
# ✓ assigning 1 to (590, 82) produces 76 more balanced triangles (2, 78): (('s+1', 78), ('s-1', 2))
# ✓ assigning 1 to (1027, 1061) produces 75 more balanced triangles (0, 75): (('s+1', 75),)
# ✓ assigning 1 to (152, 841) produces 75 more balanced triangles (0, 75): (('s+1', 75),)
# ✓ assigning 1 to (856, 798) produces 75 more balanced triangles (0, 75): (('s+1', 75),)
# ✓ assigning 1 to (83, 1988) produces 75 more balanced triangles (0, 75): (('s+1', 75),)
# ✓ assigning 1 to (896, 61) produces 75 more balanced triangles (0, 75): (('s+1', 75),)
# ✓ assigning 1 to (858, 833) produces 75 more balanced triangles (1, 76): (('s+1', 76), ('s-1', 1))
# ✓ assigning 1 to (971, 880) produces 75 more balanced triangles (0, 75): (('s+1', 75),)
# ✓ assigning 1 to (791, 2462) produces 75 more balanced triangles (2, 77): (('s+1', 77), ('s-1', 2))
# ✓ assigning 1 to (2442, 2420) produces 75 more balanced triangles (0, 75): (('s+1', 75),)
# ✓ assigning 1 to (1151, 2420) produces 75 more balanced triangles (1, 76): (('s+1', 76), ('s-1', 1))
# ✓ assigning 1 to (87, 3041) produces 74 more balanced triangles (0, 74): (('s+1', 74),)
# ✓ assigning 1 to (2452, 962) produces 74 more balanced triangles (0, 74): (('s+1', 74),)
# ✓ assigning 1 to (1043, 2443) produces 74 more balanced triangles (0, 74): (('s+1', 74),)
# ✓ assigning 1 to (856, 70) produces 74 more balanced triangles (0, 74): (('s+1', 74),)
# ✓ assigning 1 to (2443, 648) produces 74 more balanced triangles (0, 74): (('s+1', 74),)
# ✓ assigning 1 to (1287, 1171) produces 74 more balanced triangles (6, 80): (('s+1', 80), ('s-1', 6))
# ✓ assigning 1 to (82, 3475) produces 74 more balanced triangles (0, 74): (('s+1', 74),)
# ✓ assigning 1 to (2452, 982) produces 74 more balanced triangles (0, 74): (('s+1', 74),)
# ✓ assigning 1 to (888, 62) produces 74 more balanced triangles (1, 75): (('s+1', 75), ('s-1', 1))
# ✓ assigning 1 to (2407, 1006) produces 74 more balanced triangles (0, 74): (('s+1', 74),)
# ✓ assigning 1 to (990, 841) produces 74 more balanced triangles (1, 75): (('s+1', 75), ('s-1', 1))
# ✓ assigning 1 to (1029, 962) produces 74 more balanced triangles (4, 78): (('s+1', 78), ('s-1', 4))
# ✓ assigning 1 to (1389, 1239) produces 73 more balanced triangles (0, 73): (('s+1', 73),)
# ✓ assigning 1 to (1171, 977) produces 73 more balanced triangles (0, 73): (('s+1', 73),)
# ✓ assigning 1 to (2404, 973) produces 73 more balanced triangles (2, 75): (('s+1', 75), ('s-1', 2))
# ✓ assigning 1 to (2452, 95) produces 73 more balanced triangles (0, 73): (('s+1', 73),)
# ✓ assigning 1 to (87, 1065) produces 73 more balanced triangles (0, 73): (('s+1', 73),)
# ✓ assigning 1 to (860, 2470) produces 73 more balanced triangles (1, 74): (('s+1', 74), ('s-1', 1))
# ✓ assigning 1 to (2400, 833) produces 73 more balanced triangles (2, 75): (('s+1', 75), ('s-1', 2))
# ✓ assigning 1 to (913, 821) produces 73 more balanced triangles (1, 74): (('s+1', 74), ('s-1', 1))
# ✓ assigning 1 to (3414, 653) produces 73 more balanced triangles (5, 78): (('s+1', 78), ('s-1', 5))
# ✓ assigning 1 to (1005, 1012) produces 73 more balanced triangles (1, 74): (('s+1', 74), ('s-1', 1))
# ✓ assigning 1 to (1061, 896) produces 73 more balanced triangles (0, 73): (('s+1', 73),)
# ✓ assigning 1 to (982, 867) produces 73 more balanced triangles (0, 73): (('s+1', 73),)
# ✓ assigning 1 to (990, 973) produces 73 more balanced triangles (3, 76): (('s+1', 76), ('s-1', 3))
# ✓ assigning 1 to (2466, 913) produces 73 more balanced triangles (0, 73): (('s+1', 73),)
# ✓ assigning 1 to (990, 1053) produces 73 more balanced triangles (3, 76): (('s+1', 76), ('s-1', 3))
# ✓ assigning 1 to (2404, 841) produces 72 more balanced triangles (0, 72): (('s+1', 72),)
# ✓ assigning 1 to (791, 1193) produces 72 more balanced triangles (0, 72): (('s+1', 72),)
# ✓ assigning 1 to (97, 1133) produces 72 more balanced triangles (1, 73): (('s+1', 73), ('s-1', 1))
# ✓ assigning 1 to (914, 66) produces 72 more balanced triangles (0, 72): (('s+1', 72),)
# ✓ assigning 1 to (1012, 1054) produces 72 more balanced triangles (2, 74): (('s+1', 74), ('s-1', 2))
# ✓ assigning 1 to (1028, 1043) produces 72 more balanced triangles (0, 72): (('s+1', 72),)
# ✓ assigning 1 to (791, 2466) produces 72 more balanced triangles (0, 72): (('s+1', 72),)
# ✓ assigning 1 to (648, 2393) produces 72 more balanced triangles (1, 73): (('s+1', 73), ('s-1', 1))
# ✓ assigning 1 to (1027, 817) produces 72 more balanced triangles (0, 72): (('s+1', 72),)
# ✓ assigning 1 to (2393, 1029) produces 71 more balanced triangles (3, 74): (('s+1', 74), ('s-1', 3))
# ✓ assigning 1 to (1287, 913) produces 71 more balanced triangles (13, 84): (('s+1', 84), ('s-1', 13))
# ✓ assigning 1 to (97, 4238) produces 71 more balanced triangles (0, 71): (('s+1', 71),)
# ✓ assigning 1 to (1054, 896) produces 71 more balanced triangles (0, 71): (('s+1', 71),)
# ✓ assigning 1 to (1050, 75) produces 71 more balanced triangles (2, 73): (('s+1', 73), ('s-1', 2))
# ✓ assigning 1 to (62, 820) produces 71 more balanced triangles (1, 72): (('s+1', 72), ('s-1', 1))
# ✓ assigning 1 to (8, 841) produces 71 more balanced triangles (0, 71): (('s+1', 71),)
# ✓ assigning 1 to (1735, 1197) produces 71 more balanced triangles (2, 73): (('s+1', 73), ('s-1', 2))
# ✓ assigning 1 to (1043, 1028) produces 70 more balanced triangles (0, 70): (('s+1', 70),)
# ✓ assigning 1 to (4949, 653) produces 70 more balanced triangles (2, 72): (('s+1', 72), ('s-1', 2))
# ✓ assigning 1 to (1065, 860) produces 70 more balanced triangles (2, 72): (('s+1', 72), ('s-1', 2))
# ✓ assigning 1 to (1019, 1043) produces 70 more balanced triangles (2, 72): (('s+1', 72), ('s-1', 2))
# ✓ assigning 1 to (2452, 1389) produces 70 more balanced triangles (0, 70): (('s+1', 70),)
# ✓ assigning 1 to (973, 8) produces 70 more balanced triangles (2, 72): (('s+1', 72), ('s-1', 2))
# ✓ assigning 1 to (1197, 2393) produces 70 more balanced triangles (1, 71): (('s+1', 71), ('s-1', 1))
# ✓ assigning 1 to (2400, 860) produces 70 more balanced triangles (1, 71): (('s+1', 71), ('s-1', 1))
# ✓ assigning 1 to (65, 1028) produces 70 more balanced triangles (1, 71): (('s+1', 71), ('s-1', 1))
# ✓ assigning 1 to (4808, 1287) produces 70 more balanced triangles (9, 79): (('s+1', 79), ('s-1', 9))
# ✓ assigning 1 to (1043, 1133) produces 70 more balanced triangles (0, 70): (('s+1', 70),)
# ✓ assigning 1 to (977, 880) produces 70 more balanced triangles (0, 70): (('s+1', 70),)
# ✓ assigning 1 to (945, 1054) produces 70 more balanced triangles (3, 73): (('s+1', 73), ('s-1', 3))
# ✓ assigning 1 to (190, 38) produces 70 more balanced triangles (2, 72): (('s+1', 72), ('s-1', 2))
# ✓ assigning 1 to (859, 2452) produces 70 more balanced triangles (0, 70): (('s+1', 70),)
# ✓ assigning 1 to (4808, 2066) produces 69 more balanced triangles (3, 72): (('s+1', 72), ('s-1', 3))
# ✓ assigning 1 to (1006, 2434) produces 69 more balanced triangles (1, 70): (('s+1', 70), ('s-1', 1))
# ✓ assigning 1 to (2452, 990) produces 69 more balanced triangles (0, 69): (('s+1', 69),)
# ✓ assigning 1 to (791, 2434) produces 70 more balanced triangles (0, 70): (('s+1', 70),)
# ✓ assigning 1 to (973, 982) produces 69 more balanced triangles (1, 70): (('s+1', 70), ('s-1', 1))
# ✓ assigning 1 to (590, 83) produces 69 more balanced triangles (0, 69): (('s+1', 69),)
# ✓ assigning 1 to (2420, 977) produces 69 more balanced triangles (0, 69): (('s+1', 69),)
# ✓ assigning 1 to (1021, 913) produces 69 more balanced triangles (0, 69): (('s+1', 69),)
# ✓ assigning 1 to (818, 2808) produces 69 more balanced triangles (0, 69): (('s+1', 69),)
# ✓ assigning 1 to (1029, 1197) produces 69 more balanced triangles (4, 73): (('s+1', 73), ('s-1', 4))
# ✓ assigning 1 to (65, 152) produces 69 more balanced triangles (2, 71): (('s+1', 71), ('s-1', 2))
# ✓ assigning 1 to (798, 2442) produces 69 more balanced triangles (0, 69): (('s+1', 69),)
# ✓ assigning 1 to (896, 4266) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (65, 836) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (888, 2458) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (78, 65) produces 68 more balanced triangles (3, 71): (('s+1', 71), ('s-1', 3))
# ✓ assigning 1 to (1053, 2470) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (860, 590) produces 68 more balanced triangles (2, 70): (('s+1', 70), ('s-1', 2))
# ✓ assigning 1 to (1006, 4238) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (66, 61) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (1061, 66) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (8, 990) produces 68 more balanced triangles (1, 69): (('s+1', 69), ('s-1', 1))
# ✓ assigning 1 to (2466, 74) produces 68 more balanced triangles (2, 70): (('s+1', 70), ('s-1', 2))
# ✓ assigning 1 to (973, 4238) produces 68 more balanced triangles (1, 69): (('s+1', 69), ('s-1', 1))
# ✓ assigning 1 to (1061, 62) produces 68 more balanced triangles (1, 69): (('s+1', 69), ('s-1', 1))
# ✓ assigning 1 to (61, 1066) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (1802, 1814) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (2393, 65) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (2400, 82) produces 68 more balanced triangles (2, 70): (('s+1', 70), ('s-1', 2))
# ✓ assigning 1 to (1727, 74) produces 68 more balanced triangles (1, 69): (('s+1', 69), ('s-1', 1))
# ✓ assigning 1 to (66, 2442) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (4238, 71) produces 68 more balanced triangles (1, 69): (('s+1', 69), ('s-1', 1))
# ✓ assigning 1 to (880, 856) produces 68 more balanced triangles (0, 68): (('s+1', 68),)
# ✓ assigning 1 to (80, 791) produces 67 more balanced triangles (2, 69): (('s+1', 69), ('s-1', 2))
# ✓ assigning 1 to (914, 1200) produces 67 more balanced triangles (1, 68): (('s+1', 68), ('s-1', 1))
# ✓ assigning 1 to (4266, 896) produces 67 more balanced triangles (0, 67): (('s+1', 67),)
# ✓ assigning 1 to (867, 1021) produces 67 more balanced triangles (0, 67): (('s+1', 67),)
# ✓ assigning 1 to (74, 2073) produces 67 more balanced triangles (4, 71): (('s+1', 71), ('s-1', 4))
# ✓ assigning 1 to (2420, 2443) produces 67 more balanced triangles (0, 67): (('s+1', 67),)
# ✓ assigning 1 to (2458, 629) produces 67 more balanced triangles (5, 72): (('s+1', 72), ('s-1', 5))
# ✓ assigning 1 to (1988, 65) produces 67 more balanced triangles (1, 68): (('s+1', 68), ('s-1', 1))
# ✓ assigning 1 to (62, 1005) produces 67 more balanced triangles (1, 68): (('s+1', 68), ('s-1', 1))
# ✓ assigning 1 to (4266, 2393) produces 67 more balanced triangles (0, 67): (('s+1', 67),)
# ✓ assigning 1 to (8, 70) produces 67 more balanced triangles (0, 67): (('s+1', 67),)
# ✓ assigning 1 to (97, 1019) produces 67 more balanced triangles (3, 70): (('s+1', 70), ('s-1', 3))
# ✓ assigning 1 to (2452, 2808) produces 67 more balanced triangles (1, 68): (('s+1', 68), ('s-1', 1))
# ✓ assigning 1 to (66, 2808) produces 67 more balanced triangles (0, 67): (('s+1', 67),)
# ✓ assigning 1 to (858, 896) produces 67 more balanced triangles (0, 67): (('s+1', 67),)
# ✓ assigning 1 to (66, 2066) produces 67 more balanced triangles (1, 68): (('s+1', 68), ('s-1', 1))
# ✓ assigning 1 to (2808, 66) produces 67 more balanced triangles (0, 67): (('s+1', 67),)
# ✓ assigning 1 to (82, 3414) produces 67 more balanced triangles (1, 68): (('s+1', 68), ('s-1', 1))
# ✓ assigning 1 to (2400, 74) produces 67 more balanced triangles (1, 68): (('s+1', 68), ('s-1', 1))
# ✓ assigning 1 to (2420, 2354) produces 67 more balanced triangles (5, 72): (('s+1', 72), ('s-1', 5))
# ✓ assigning 1 to (859, 880) produces 66 more balanced triangles (0, 66): (('s+1', 66),)
# ✓ assigning 1 to (988, 817) produces 66 more balanced triangles (1, 67): (('s+1', 67), ('s-1', 1))
# ✓ assigning 1 to (1033, 2401) produces 66 more balanced triangles (1, 67): (('s+1', 67), ('s-1', 1))
# ✓ assigning 1 to (2452, 43) produces 66 more balanced triangles (1, 67): (('s+1', 67), ('s-1', 1))
# ✓ assigning 1 to (971, 896) produces 66 more balanced triangles (0, 66): (('s+1', 66),)
# ✓ assigning 1 to (66, 62) produces 66 more balanced triangles (0, 66): (('s+1', 66),)
# ✓ assigning 1 to (2451, 791) produces 66 more balanced triangles (0, 66): (('s+1', 66),)
# ✓ assigning 1 to (1239, 1029) produces 66 more balanced triangles (3, 69): (('s+1', 69), ('s-1', 3))
# ✓ assigning 1 to (880, 3041) produces 66 more balanced triangles (0, 66): (('s+1', 66),)
# ✓ assigning 1 to (1065, 1006) produces 66 more balanced triangles (0, 66): (('s+1', 66),)
# ✓ assigning 1 to (1802, 4903) produces 66 more balanced triangles (1, 67): (('s+1', 67), ('s-1', 1))
# ✓ assigning 1 to (55, 65) produces 65 more balanced triangles (2, 67): (('s+1', 67), ('s-1', 2))
# ✓ assigning 1 to (2421, 648) produces 65 more balanced triangles (0, 65): (('s+1', 65),)
# ✓ assigning 1 to (913, 2389) produces 65 more balanced triangles (0, 65): (('s+1', 65),)
# ✓ assigning 1 to (1239, 798) produces 65 more balanced triangles (1, 66): (('s+1', 66), ('s-1', 1))
# ✓ assigning 1 to (2451, 867) produces 65 more balanced triangles (0, 65): (('s+1', 65),)
# ✓ assigning 1 to (2389, 913) produces 65 more balanced triangles (0, 65): (('s+1', 65),)
# ✓ assigning 1 to (841, 1287) produces 65 more balanced triangles (8, 73): (('s+1', 73), ('s-1', 8))
# ✓ assigning 1 to (1005, 62) produces 65 more balanced triangles (1, 66): (('s+1', 66), ('s-1', 1))
# ✓ assigning 1 to (2073, 74) produces 65 more balanced triangles (4, 69): (('s+1', 69), ('s-1', 4))
# ✓ assigning 1 to (880, 859) produces 65 more balanced triangles (0, 65): (('s+1', 65),)
# ✓ assigning 1 to (1005, 65) produces 65 more balanced triangles (0, 65): (('s+1', 65),)
# ✓ assigning 1 to (92, 15) produces 65 more balanced triangles (0, 65): (('s+1', 65),)
# ✓ assigning 1 to (8685, 648) produces 65 more balanced triangles (0, 65): (('s+1', 65),)
# ✓ assigning 1 to (152, 1029) produces 65 more balanced triangles (1, 66): (('s+1', 66), ('s-1', 1))
# ✓ assigning 1 to (648, 1193) produces 65 more balanced triangles (1, 66): (('s+1', 66), ('s-1', 1))
# ✓ assigning 1 to (95, 1029) produces 64 more balanced triangles (2, 66): (('s+1', 66), ('s-1', 2))
# ✓ assigning 1 to (841, 3041) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (896, 859) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (888, 1043) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (82, 1022) produces 64 more balanced triangles (2, 66): (('s+1', 66), ('s-1', 2))
# ✓ assigning 1 to (4238, 65) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (955, 64) produces 64 more balanced triangles (5, 69): (('s+1', 69), ('s-1', 5))
# ✓ assigning 1 to (2458, 4238) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (842, 1066) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (2458, 7860) produces 65 more balanced triangles (1, 66): (('s+1', 66), ('s-1', 1))
# ✓ assigning 1 to (896, 982) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (8, 858) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (83, 2451) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (8685, 2458) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (1061, 962) produces 64 more balanced triangles (1, 65): (('s+1', 65), ('s-1', 1))
# ✓ assigning 1 to (1171, 1193) produces 64 more balanced triangles (0, 64): (('s+1', 64),)
# ✓ assigning 1 to (2442, 1935) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (2434, 648) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (881, 67) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (97, 190) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (1426, 4808) produces 63 more balanced triangles (1, 64): (('s+1', 64), ('s-1', 1))
# ✓ assigning 1 to (971, 881) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (1033, 3475) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (988, 3773) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (87, 2328) produces 63 more balanced triangles (1, 64): (('s+1', 64), ('s-1', 1))
# ✓ assigning 1 to (3041, 1033) produces 63 more balanced triangles (1, 64): (('s+1', 64), ('s-1', 1))
# ✓ assigning 1 to (990, 1061) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (3041, 71) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (1197, 4238) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (3414, 83) produces 63 more balanced triangles (1, 64): (('s+1', 64), ('s-1', 1))
# ✓ assigning 1 to (190, 1116) produces 63 more balanced triangles (3, 66): (('s+1', 66), ('s-1', 3))
# ✓ assigning 1 to (83, 3414) produces 63 more balanced triangles (1, 64): (('s+1', 64), ('s-1', 1))
# ✓ assigning 1 to (61, 1054) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (2404, 4256) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (1012, 8685) produces 63 more balanced triangles (0, 63): (('s+1', 63),)
# ✓ assigning 1 to (817, 4238) produces 62 more balanced triangles (0, 62): (('s+1', 62),)
# ✓ assigning 1 to (955, 65) produces 62 more balanced triangles (5, 67): (('s+1', 67), ('s-1', 5))
# ✓ assigning 1 to (977, 1053) produces 62 more balanced triangles (0, 62): (('s+1', 62),)
# ✓ assigning 1 to (955, 1012) produces 63 more balanced triangles (5, 68): (('s+1', 68), ('s-1', 5))
# ✓ assigning 1 to (1054, 64) produces 62 more balanced triangles (5, 67): (('s+1', 67), ('s-1', 5))
# ✓ assigning 1 to (1389, 2466) produces 62 more balanced triangles (0, 62): (('s+1', 62),)
# ✓ assigning 1 to (798, 817) produces 62 more balanced triangles (2, 64): (('s+1', 64), ('s-1', 2))
# ✓ assigning 1 to (653, 914) produces 62 more balanced triangles (2, 64): (('s+1', 64), ('s-1', 2))
# ✓ assigning 1 to (74, 2476) produces 62 more balanced triangles (0, 62): (('s+1', 62),)
# ✓ assigning 1 to (1171, 250) produces 62 more balanced triangles (1, 63): (('s+1', 63), ('s-1', 1))
# ✓ assigning 1 to (1133, 62) produces 62 more balanced triangles (2, 64): (('s+1', 64), ('s-1', 2))
# ✓ assigning 1 to (1033, 836) produces 62 more balanced triangles (1, 63): (('s+1', 63), ('s-1', 1))
# ✓ assigning 1 to (982, 1707) produces 62 more balanced triangles (0, 62): (('s+1', 62),)
# ✓ assigning 1 to (1935, 1012) produces 62 more balanced triangles (5, 67): (('s+1', 67), ('s-1', 5))
# ✓ assigning 1 to (817, 3773) produces 62 more balanced triangles (0, 62): (('s+1', 62),)
# ✓ assigning 1 to (2443, 833) produces 62 more balanced triangles (1, 63): (('s+1', 63), ('s-1', 1))
# ✓ assigning 1 to (190, 97) produces 61 more balanced triangles (0, 61): (('s+1', 61),)
# ✓ assigning 1 to (70, 1935) produces 61 more balanced triangles (1, 62): (('s+1', 62), ('s-1', 1))
# ✓ assigning 1 to (1066, 833) produces 61 more balanced triangles (2, 63): (('s+1', 63), ('s-1', 2))
# ✓ assigning 1 to (2443, 798) produces 61 more balanced triangles (1, 62): (('s+1', 62), ('s-1', 1))
# ✓ assigning 1 to (4256, 945) produces 61 more balanced triangles (1, 62): (('s+1', 62), ('s-1', 1))
# ✓ assigning 1 to (4238, 1197) produces 61 more balanced triangles (0, 61): (('s+1', 61),)
# ✓ assigning 1 to (1052, 973) produces 61 more balanced triangles (3, 64): (('s+1', 64), ('s-1', 3))
# ✓ assigning 1 to (80, 64) produces 61 more balanced triangles (2, 63): (('s+1', 63), ('s-1', 2))
# ✓ assigning 1 to (856, 990) produces 61 more balanced triangles (2, 63): (('s+1', 63), ('s-1', 2))
# ✓ assigning 1 to (896, 2407) produces 61 more balanced triangles (1, 62): (('s+1', 62), ('s-1', 1))
# ✓ assigning 1 to (881, 962) produces 61 more balanced triangles (1, 62): (('s+1', 62), ('s-1', 1))
# ✓ assigning 1 to (3773, 1389) produces 61 more balanced triangles (1, 62): (('s+1', 62), ('s-1', 1))
# ✓ assigning 1 to (842, 1197) produces 61 more balanced triangles (0, 61): (('s+1', 61),)
# ✓ assigning 1 to (97, 2400) produces 60 more balanced triangles (0, 60): (('s+1', 60),)
# ✓ assigning 1 to (2407, 896) produces 60 more balanced triangles (1, 61): (('s+1', 61), ('s-1', 1))
# ✓ assigning 1 to (1054, 990) produces 60 more balanced triangles (1, 61): (('s+1', 61), ('s-1', 1))
# ✓ assigning 1 to (881, 1005) produces 60 more balanced triangles (0, 60): (('s+1', 60),)
# ✓ assigning 1 to (97, 2462) produces 60 more balanced triangles (1, 61): (('s+1', 61), ('s-1', 1))
# ✓ assigning 1 to (67, 818) produces 60 more balanced triangles (0, 60): (('s+1', 60),)
# ✓ assigning 1 to (64, 2462) produces 61 more balanced triangles (5, 66): (('s+1', 66), ('s-1', 5))
# ✓ assigning 1 to (975, 2452) produces 60 more balanced triangles (1, 61): (('s+1', 61), ('s-1', 1))
# ✓ assigning 1 to (7860, 2443) produces 60 more balanced triangles (0, 60): (('s+1', 60),)
# ✓ assigning 1 to (8, 817) produces 60 more balanced triangles (0, 60): (('s+1', 60),)
# ✓ assigning 1 to (2404, 1389) produces 60 more balanced triangles (0, 60): (('s+1', 60),)
# ✓ assigning 1 to (975, 648) produces 60 more balanced triangles (2, 62): (('s+1', 62), ('s-1', 2))
# ✓ assigning 1 to (1061, 95) produces 60 more balanced triangles (0, 60): (('s+1', 60),)
# ✓ assigning 1 to (82, 1990) produces 60 more balanced triangles (2, 62): (('s+1', 62), ('s-1', 2))
# ✓ assigning 1 to (973, 3475) produces 60 more balanced triangles (1, 61): (('s+1', 61), ('s-1', 1))
# ✓ assigning 1 to (2404, 66) produces 60 more balanced triangles (0, 60): (('s+1', 60),)
# ✓ assigning 1 to (951, 913) produces 59 more balanced triangles (0, 59): (('s+1', 59),)
# ✓ assigning 1 to (629, 34) produces 59 more balanced triangles (2, 61): (('s+1', 61), ('s-1', 2))
# ✓ assigning 1 to (1012, 749) produces 59 more balanced triangles (3, 62): (('s+1', 62), ('s-1', 3))
# ✓ assigning 1 to (190, 2420) produces 59 more balanced triangles (0, 59): (('s+1', 59),)
# ✓ assigning 1 to (856, 1151) produces 59 more balanced triangles (0, 59): (('s+1', 59),)
# ✓ assigning 1 to (70, 2066) produces 59 more balanced triangles (3, 62): (('s+1', 62), ('s-1', 3))
# ✓ assigning 1 to (881, 2407) produces 59 more balanced triangles (0, 59): (('s+1', 59),)
# ✓ assigning 1 to (2400, 1033) produces 59 more balanced triangles (0, 59): (('s+1', 59),)
# ✓ assigning 1 to (976, 83) produces 59 more balanced triangles (18, 77): (('s+1', 77), ('s-1', 18))
# ✓ assigning 1 to (1239, 3773) produces 59 more balanced triangles (1, 60): (('s+1', 60), ('s-1', 1))
# ✓ assigning 1 to (4256, 888) produces 59 more balanced triangles (1, 60): (('s+1', 60), ('s-1', 1))
# ...
# ✓ assigning 1 to (791, 1360) produces 23 more balanced triangles (3, 26): (('s+1', 26), ('s-1', 3))
# ✓ assigning 1 to (1735, 1794) produces 23 more balanced triangles (7, 30): (('s+1', 30), ('s-1', 7))
# ✓ assigning 1 to (6859, 1802) produces 23 more balanced triangles (1, 24): (('s+1', 24), ('s-1', 1))
# ✓ assigning 1 to (1796, 1817) produces 23 more balanced triangles (7, 30): (('s+1', 30), ('s-1', 7))
# ✗ assigning 1 to (7604, 1810) produces 22 more balanced triangles (4, 26): (('s+1', 26), ('s-1', 4))
# ✓ assigning 1 to (6866, 1814) produces 22 more balanced triangles (2, 24): (('s+1', 24), ('s-1', 2))
# ✗ assigning 1 to (632, 1825) produces 22 more balanced triangles (4, 26): (('s+1', 26), ('s-1', 4))
# ✓ assigning 1 to (6852, 161) produces 22 more balanced triangles (0, 22): (('s+1', 22),)
# ✓ assigning 1 to (1735, 1650) produces 22 more balanced triangles (3, 25): (('s+1', 25), ('s-1', 3))
# ✓ assigning 1 to (4552, 607) produces 22 more balanced triangles (2, 24): (('s+1', 24), ('s-1', 2))
# ✓ assigning 1 to (2454, 2441) produces 22 more balanced triangles (3, 25): (('s+1', 25), ('s-1', 3))
# ✓ assigning 1 to (2784, 1053) produces 22 more balanced triangles (1, 23): (('s+1', 23), ('s-1', 1))
# ✓ assigning 1 to (1792, 7604) produces 22 more balanced triangles (3, 25): (('s+1', 25), ('s-1', 3))
# ✓ assigning 1 to (5791, 625) produces 22 more balanced triangles (4, 26): (('s+1', 26), ('s-1', 4))
# ✓ assigning 1 to (2404, 34) produces 22 more balanced triangles (7, 29): (('s+1', 29), ('s-1', 7))
# ✓ assigning 1 to (2666, 3335) produces 22 more balanced triangles (8, 30): (('s+1', 30), ('s-1', 8))
# ✓ assigning 1 to (1179, 184) produces 22 more balanced triangles (4, 26): (('s+1', 26), ('s-1', 4))
# ✓ assigning 1 to (4552, 1300) produces 22 more balanced triangles (3, 25): (('s+1', 25), ('s-1', 3))
# ✓ assigning -1 to (3944, 4691) produces 22 more balanced triangles (24, 2): (('s-1', 24), ('s+1', 2))
# ✓ assigning 1 to (6178, 981) produces 22 more balanced triangles (3, 25): (('s+1', 25), ('s-1', 3))
# ✓ assigning 1 to (663, 154) produces 22 more balanced triangles (4, 26): (('s+1', 26), ('s-1', 4))
# ✓ assigning 1 to (841, 1460) produces 21 more balanced triangles (8, 29): (('s+1', 29), ('s-1', 8))
# ✓ assigning 1 to (1155, 1752) produces 21 more balanced triangles (6, 27): (('s+1', 27), ('s-1', 6))
# ✓ assigning 1 to (2099, 809) produces 21 more balanced triangles (4, 25): (('s+1', 25), ('s-1', 4))
# ✓ assigning 1 to (4797, 943) produces 21 more balanced triangles (2, 23): (('s+1', 23), ('s-1', 2))
# ✓ assigning 1 to (2446, 43) produces 21 more balanced triangles (1, 22): (('s+1', 22), ('s-1', 1))
# ✓ assigning 1 to (4947, 1240) produces 21 more balanced triangles (6, 27): (('s+1', 27), ('s-1', 6))
# ✗ assigning -1 to (1491, 43) produces 21 more balanced triangles (33, 12): (('s-1', 33), ('s+1', 12))
# ✓ assigning 1 to (92, 2300) produces 21 more balanced triangles (5, 26): (('s+1', 26), ('s-1', 5))
# ✓ assigning 1 to (4218, 625) produces 21 more balanced triangles (8, 29): (('s+1', 29), ('s-1', 8))
# ✓ assigning 1 to (2784, 38) produces 21 more balanced triangles (2, 23): (('s+1', 23), ('s-1', 2))
# ✓ assigning 1 to (895, 84) produces 21 more balanced triangles (3, 24): (('s+1', 24), ('s-1', 3))
# ✓ assigning 1 to (3522, 1116) produces 21 more balanced triangles (6, 27): (('s+1', 27), ('s-1', 6))
# ✓ assigning 1 to (81, 651) produces 21 more balanced triangles (3, 24): (('s+1', 24), ('s-1', 3))
# ✓ assigning 1 to (631, 651) produces 21 more balanced triangles (2, 23): (('s+1', 23), ('s-1', 2))
# ✓ assigning 1 to (3393, 3335) produces 21 more balanced triangles (6, 27): (('s+1', 27), ('s-1', 6))
# ✓ assigning 1 to (7477, 57) produces 21 more balanced triangles (6, 27): (('s+1', 27), ('s-1', 6))
# ✗ assigning 1 to (34, 2462) produces 21 more balanced triangles (12, 33): (('s+1', 33), ('s-1', 12))
# ✓ assigning 1 to (2354, 1953) produces 21 more balanced triangles (7, 28): (('s+1', 28), ('s-1', 7))
# ✓ assigning 1 to (2516, 522) produces 21 more balanced triangles (4, 25): (('s+1', 25), ('s-1', 4))
# ✓ assigning -1 to (69, 1981) produces 21 more balanced triangles (28, 7): (('s-1', 28), ('s+1', 7))
# ✓ assigning 1 to (3021, 2113) produces 21 more balanced triangles (7, 28): (('s+1', 28), ('s-1', 7))
# ✓ assigning 1 to (154, 2066) produces 20 more balanced triangles (5, 25): (('s+1', 25), ('s-1', 5))
# ✓ assigning 1 to (6866, 2553) produces 20 more balanced triangles (1, 21): (('s+1', 21), ('s-1', 1))
# ✓ assigning 1 to (57, 1838) produces 20 more balanced triangles (5, 25): (('s+1', 25), ('s-1', 5))
# ✓ assigning 1 to (6486, 1287) produces 20 more balanced triangles (5, 25): (('s+1', 25), ('s-1', 5))
# ✓ assigning 1 to (1990, 57) produces 20 more balanced triangles (9, 29): (('s+1', 29), ('s-1', 9))
# ✓ assigning 1 to (5171, 4901) produces 20 more balanced triangles (3, 23): (('s+1', 23), ('s-1', 3))
# ✗ assigning 1 to (6703, 1801) produces 20 more balanced triangles (3, 23): (('s+1', 23), ('s-1', 3))
# ✓ assigning 1 to (1803, 1804) produces 20 more balanced triangles (3, 23): (('s+1', 23), ('s-1', 3))
# ✓ assigning -1 to (1981, 1309) produces 20 more balanced triangles (26, 6): (('s-1', 26), ('s+1', 6))
# ✗ assigning 1 to (4799, 877) produces 20 more balanced triangles (3, 23): (('s+1', 23), ('s-1', 3))
# ✓ assigning 1 to (5483, 2502) produces 19 more balanced triangles (4, 23): (('s+1', 23), ('s-1', 4))
# ✓ assigning 1 to (1236, 43) produces 19 more balanced triangles (4, 23): (('s+1', 23), ('s-1', 4))
# ✓ assigning 1 to (1808, 5483) produces 20 more balanced triangles (10, 30): (('s+1', 30), ('s-1', 10))
# ✗ assigning -1 to (1092, 2152) produces 19 more balanced triangles (24, 5): (('s-1', 24), ('s+1', 5))
# ✓ assigning 1 to (5483, 670) produces 19 more balanced triangles (4, 23): (('s+1', 23), ('s-1', 4))
# ✓ assigning 1 to (84, 1300) produces 19 more balanced triangles (5, 24): (('s+1', 24), ('s-1', 5))
# ✓ assigning 1 to (2099, 976) produces 19 more balanced triangles (6, 25): (('s+1', 25), ('s-1', 6))
# ✓ assigning 1 to (659, 5483) produces 19 more balanced triangles (10, 29): (('s+1', 29), ('s-1', 10))
# ✓ assigning 1 to (1993, 749) produces 19 more balanced triangles (6, 25): (('s+1', 25), ('s-1', 6))
# ✓ assigning -1 to (13001, 26) produces 19 more balanced triangles (20, 1): (('s-1', 20), ('s+1', 1))
# ✓ assigning 1 to (1794, 1735) produces 19 more balanced triangles (7, 26): (('s+1', 26), ('s-1', 7))
# ✓ assigning 1 to (2308, 3974) produces 19 more balanced triangles (6, 25): (('s+1', 25), ('s-1', 6))
# ✗ assigning 1 to (833, 80) produces 19 more balanced triangles (14, 33): (('s+1', 33), ('s-1', 14))
# ✓ assigning 1 to (976, 2099) produces 19 more balanced triangles (6, 25): (('s+1', 25), ('s-1', 6))
# ✓ assigning 1 to (80, 1020) produces 19 more balanced triangles (8, 27): (('s+1', 27), ('s-1', 8))
# ✓ assigning 1 to (3411, 1116) produces 18 more balanced triangles (5, 23): (('s+1', 23), ('s-1', 5))
# ✓ assigning 1 to (78, 885) produces 18 more balanced triangles (5, 23): (('s+1', 23), ('s-1', 5))
# ✓ assigning 1 to (4808, 3335) produces 18 more balanced triangles (8, 26): (('s+1', 26), ('s-1', 8))
# ✓ assigning -1 to (2310, 1240) produces 18 more balanced triangles (33, 15): (('s-1', 33), ('s+1', 15))
# ✓ assigning 1 to (9160, 877) produces 18 more balanced triangles (4, 22): (('s+1', 22), ('s-1', 4))
# ✓ assigning 1 to (936, 930) produces 18 more balanced triangles (4, 22): (('s+1', 22), ('s-1', 4))
# ✓ assigning 1 to (1300, 50) produces 18 more balanced triangles (4, 22): (('s+1', 22), ('s-1', 4))
# ✓ assigning 1 to (1935, 34) produces 18 more balanced triangles (12, 30): (('s+1', 30), ('s-1', 12))
# ✓ assigning 1 to (901, 1735) produces 18 more balanced triangles (5, 23): (('s+1', 23), ('s-1', 5))
# ✓ assigning 1 to (34, 1151) produces 18 more balanced triangles (16, 34): (('s+1', 34), ('s-1', 16))
# ✓ assigning 1 to (1820, 1808) produces 18 more balanced triangles (6, 24): (('s+1', 24), ('s-1', 6))
# ✓ assigning 1 to (91, 75) produces 18 more balanced triangles (5, 23): (('s+1', 23), ('s-1', 5))
# ✓ assigning -1 to (48, 2502) produces 17 more balanced triangles (22, 5): (('s-1', 22), ('s+1', 5))
# ✓ assigning 1 to (57, 826) produces 17 more balanced triangles (17, 34): (('s+1', 34), ('s-1', 17))
# ✓ assigning 1 to (1436, 75) produces 17 more balanced triangles (7, 24): (('s+1', 24), ('s-1', 7))
# ✓ assigning -1 to (12973, 2553) produces 17 more balanced triangles (20, 3): (('s-1', 20), ('s+1', 3))
# ✓ assigning 1 to (2384, 3096) produces 17 more balanced triangles (3, 20): (('s+1', 20), ('s-1', 3))
# ✓ assigning 1 to (1287, 2666) produces 17 more balanced triangles (7, 24): (('s+1', 24), ('s-1', 7))
# ✓ assigning 1 to (5171, 1730) produces 17 more balanced triangles (5, 22): (('s+1', 22), ('s-1', 5))
# ✓ assigning 1 to (14247, 5483) produces 17 more balanced triangles (5, 22): (('s+1', 22), ('s-1', 5))
# ✓ assigning 1 to (3822, 625) produces 17 more balanced triangles (7, 24): (('s+1', 24), ('s-1', 7))
# ✓ assigning 1 to (1953, 1685) produces 17 more balanced triangles (6, 23): (('s+1', 23), ('s-1', 6))
# ✓ assigning 1 to (836, 1808) produces 17 more balanced triangles (10, 27): (('s+1', 27), ('s-1', 10))
# ✗ assigning 1 to (6203, 1070) produces 16 more balanced triangles (9, 25): (('s+1', 25), ('s-1', 9))
# ✓ assigning -1 to (2310, 1342) produces 16 more balanced triangles (22, 6): (('s-1', 22), ('s+1', 6))
# ✓ assigning 1 to (749, 0) produces 16 more balanced triangles (8, 24): (('s+1', 24), ('s-1', 8))
# ✓ assigning 1 to (6474, 629) produces 16 more balanced triangles (6, 22): (('s+1', 22), ('s-1', 6))
# ✓ assigning 1 to (945, 826) produces 16 more balanced triangles (8, 24): (('s+1', 24), ('s-1', 8))
# ✓ assigning 1 to (5483, 15) produces 16 more balanced triangles (5, 21): (('s+1', 21), ('s-1', 5))
# ✓ assigning -1 to (1491, 1240) produces 16 more balanced triangles (31, 15): (('s-1', 31), ('s+1', 15))
# ✓ assigning 1 to (4246, 976) produces 16 more balanced triangles (8, 24): (('s+1', 24), ('s-1', 8))
# ✓ assigning -1 to (1342, 2310) produces 16 more balanced triangles (22, 6): (('s-1', 22), ('s+1', 6))
# ✓ assigning 1 to (5483, 118) produces 16 more balanced triangles (6, 22): (('s+1', 22), ('s-1', 6))
# ✓ assigning 1 to (2310, 7497) produces 16 more balanced triangles (4, 20): (('s+1', 20), ('s-1', 4))
# ✓ assigning -1 to (13001, 6586) produces 15 more balanced triangles (24, 9): (('s-1', 24), ('s+1', 9))
# ✗ assigning 1 to (3411, 523) produces 15 more balanced triangles (6, 21): (('s+1', 21), ('s-1', 6))
# ✓ assigning 1 to (3096, 3497) produces 15 more balanced triangles (8, 23): (('s+1', 23), ('s-1', 8))
# ✗ assigning 1 to (1675, 2066) produces 15 more balanced triangles (8, 23): (('s+1', 23), ('s-1', 8))
# ✓ assigning -1 to (9270, 1300) produces 15 more balanced triangles (22, 7): (('s-1', 22), ('s+1', 7))
# ✓ assigning 1 to (4218, 6474) produces 15 more balanced triangles (10, 25): (('s+1', 25), ('s-1', 10))
# ✓ assigning 1 to (2290, 75) produces 15 more balanced triangles (20, 35): (('s+1', 35), ('s-1', 20))
# ✓ assigning 1 to (381, 3335) produces 14 more balanced triangles (5, 19): (('s+1', 19), ('s-1', 5))
# ✓ assigning 1 to (2310, 885) produces 14 more balanced triangles (7, 21): (('s+1', 21), ('s-1', 7))
# ✓ assigning -1 to (2310, 5080) produces 14 more balanced triangles (19, 5): (('s-1', 19), ('s+1', 5))
# ✓ assigning 1 to (3096, 1207) produces 14 more balanced triangles (7, 21): (('s+1', 21), ('s-1', 7))
# ✗ assigning 1 to (632, 161) produces 14 more balanced triangles (10, 24): (('s+1', 24), ('s-1', 10))
# ✓ assigning 1 to (3475, 57) produces 13 more balanced triangles (8, 21): (('s+1', 21), ('s-1', 8))
# ✓ assigning 1 to (78, 670) produces 13 more balanced triangles (7, 20): (('s+1', 20), ('s-1', 7))
# ✗ assigning 1 to (2300, 976) produces 12 more balanced triangles (15, 27): (('s+1', 27), ('s-1', 15))
# ✓ assigning 1 to (2384, 1070) produces 12 more balanced triangles (9, 21): (('s+1', 21), ('s-1', 9))
# ✓ assigning 1 to (794, 43) produces 12 more balanced triangles (10, 22): (('s+1', 22), ('s-1', 10))
# ✓ assigning 1 to (669, 990) produces 12 more balanced triangles (10, 22): (('s+1', 22), ('s-1', 10))
# ✓ assigning -1 to (3041, 2559) produces 12 more balanced triangles (20, 8): (('s-1', 20), ('s+1', 8))
# ✓ assigning 1 to (1236, 618) produces 12 more balanced triangles (8, 20): (('s+1', 20), ('s-1', 8))
# ✓ assigning 1 to (14602, 57) produces 11 more balanced triangles (8, 19): (('s+1', 19), ('s-1', 8))
# ✓ assigning 1 to (1730, 1092) produces 11 more balanced triangles (9, 20): (('s+1', 20), ('s-1', 9))
# ✓ assigning 1 to (522, 4324) produces 11 more balanced triangles (5, 16): (('s+1', 16), ('s-1', 5))
# ✓ assigning 1 to (5394, 2300) produces 11 more balanced triangles (6, 17): (('s+1', 17), ('s-1', 6))
# ✓ assigning -1 to (523, 57) produces 10 more balanced triangles (36, 26): (('s-1', 36), ('s+1', 26))
# ✗ assigning -1 to (1808, 50) produces 10 more balanced triangles (24, 14): (('s-1', 24), ('s+1', 14))
# ✓ assigning -1 to (632, 48) produces 10 more balanced triangles (20, 10): (('s-1', 20), ('s+1', 10))
# ✓ assigning 1 to (1735, 1240) produces 10 more balanced triangles (6, 16): (('s+1', 16), ('s-1', 6))
# ✗ assigning 1 to (976, 4701) produces 10 more balanced triangles (13, 23): (('s+1', 23), ('s-1', 13))
# ✓ assigning 1 to (669, 78) produces 9 more balanced triangles (9, 18): (('s+1', 18), ('s-1', 9))
# ✓ assigning -1 to (48, 1752) produces 9 more balanced triangles (18, 9): (('s-1', 18), ('s+1', 9))
# ✓ assigning 1 to (4257, 170) produces 9 more balanced triangles (7, 16): (('s+1', 16), ('s-1', 7))
# ✓ assigning 1 to (1071, 625) produces 8 more balanced triangles (23, 31): (('s+1', 31), ('s-1', 23))
# ✓ assigning -1 to (1381, 1240) produces 8 more balanced triangles (20, 12): (('s-1', 20), ('s+1', 12))
# ✓ assigning -1 to (4420, 57) produces 7 more balanced triangles (16, 9): (('s-1', 16), ('s+1', 9))
# ✓ assigning -1 to (1981, 74) produces 7 more balanced triangles (27, 20): (('s-1', 27), ('s+1', 20))
# ✓ assigning -1 to (1770, 1442) produces 7 more balanced triangles (18, 11): (('s-1', 18), ('s+1', 11))
# ✗ assigning -1 to (81, 1981) produces 8 more balanced triangles (20, 12): (('s-1', 20), ('s+1', 12))
# ✓ assigning 1 to (1876, 57) produces 6 more balanced triangles (14, 20): (('s+1', 20), ('s-1', 14))
# ✓ assigning 1 to (2935, 43) produces 6 more balanced triangles (9, 15): (('s+1', 15), ('s-1', 9))
# ✓ assigning 1 to (1179, 170) produces 6 more balanced triangles (11, 17): (('s+1', 17), ('s-1', 11))
# ✗ assigning 1 to (1460, 1061) produces 5 more balanced triangles (11, 16): (('s+1', 16), ('s-1', 11))
# ✓ assigning -1 to (2152, 1735) produces 5 more balanced triangles (18, 13): (('s-1', 18), ('s+1', 13))
# ✓ assigning 1 to (2679, 106) produces 5 more balanced triangles (11, 16): (('s+1', 16), ('s-1', 11))
# ✓ assigning 1 to (1287, 2233) produces 5 more balanced triangles (16, 21): (('s+1', 21), ('s-1', 16))
# ✗ assigning 1 to (2310, 64) produces 4 more balanced triangles (25, 29): (('s+1', 29), ('s-1', 25))
# ✓ assigning -1 to (2310, 4701) produces 4 more balanced triangles (24, 20): (('s-1', 24), ('s+1', 20))
# ✓ assigning 1 to (3096, 3673) produces 3 more balanced triangles (11, 14): (('s+1', 14), ('s-1', 11))
# ✓ assigning -1 to (2308, 523) produces 3 more balanced triangles (15, 12): (('s-1', 15), ('s+1', 12))
# ✗ assigning 1 to (663, 163) produces 3 more balanced triangles (10, 13): (('s+1', 13), ('s-1', 10))
# ✗ assigning 1 to (3021, 2354) produces 2 more balanced triangles (12, 14): (('s+1', 14), ('s-1', 12))
# ✓ assigning -1 to (34, 223) produces 2 more balanced triangles (14, 12): (('s-1', 14), ('s+1', 12))
# ✓ assigning -1 to (1080, 2066) produces 2 more balanced triangles (17, 15): (('s-1', 17), ('s+1', 15))
# ✓ assigning -1 to (1381, 653) produces 2 more balanced triangles (14, 12): (('s-1', 14), ('s+1', 12))
# ✓ assigning 1 to (1287, 2701) produces 1 more balanced triangles (11, 12): (('s+1', 12), ('s-1', 11))
# ✗ assigning 1 to (5240, 1770) produces 1 more balanced triangles (11, 12): (('s+1', 12), ('s-1', 11))
# ✓ assigning 1 to (1808, 749) produces 1 more balanced triangles (15, 16): (('s+1', 16), ('s-1', 15))
# Accuracy on 1819 predictions is 0.9835074216602528
#  => accuracy 0.9835074216602528 (strong balance)

# %%
part, weak_preds, _ = iterative_approach(
    graph_partition_f=partition_graph,
    graph_partition_kwargs=dict(sc=sc,
                                lambda_=lambda_,
                                iterations=max_iter,
                                seed=random_seed),
    budget_allocation_kwargs=dict(const=200),
    **common_params)
print(" => accuracy {} (weak balance)".format(accuracy(test_g, weak_preds)))

# Accuracy on 2645 predictions is 0.9629489603024575
# Out:
# iteration=1, #remaining targets=1819
# graph partitioning...
# to_scipy_sparse_matrix
# 100%|██████████| 77357/77357 [00:01<00:00, 58012.29it/s]
